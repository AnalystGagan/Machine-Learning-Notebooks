# %% [markdown]
# ![](matplot_workflow.png)

# %% [markdown]
# ##  Introduction to matplotlib

# %%
# %matplotlib inline
#above is a magic command for jupyter notebook to make sure all plots appear within the notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
#Here is the first setp of workflow 
#also lets get rid of that [] by using ";"
plt.plot();

# %%
#better way 
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,5]);

# %%
#lets make some sample data
x= [1,2,3,4,5]
y= [20,30,40,50,60]
plt.plot(x,y);

# %%
# Two methods of ploting

# %%
#method 1
fig = plt.figure()#create a figure
axis = fig.add_subplot() #addes some axes
plt.show()

# %%
#2nd method
fig = plt.figure()#creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) #add some data
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#3rd method (we will be using)
fig, ax  = plt.subplots()
ax.plot(x,y);#add some data
type(ax), type(fig)
# Out:
# (matplotlib.axes._subplots.AxesSubplot, matplotlib.figure.Figure)

# %% [markdown]
# <img src="anatomy of matplot fig.PNG"/>

# %% [markdown]
# ## Matplotlib Example Workflow

# %%
# 1.Import matplotlib and get it ready for plotting in jupyter

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# 2.Prepare Data
x  = [1,2,3,4,5]
y = [11,22,33,44,55]  

#3.Setup a plot
fig, ax = plt.subplots(figsize = (10,10)) #(10,10) height and width

#4. Plot the data
ax.plot(x,y)

#5. customize plot
ax.set(title = "simple plot",xlabel = "X-axis",ylabel = "Y=axis")

#6. Save and show (you save the whole figure)
fig.savefig("firstplot.png")

# %% [markdown]
# ## Making figure with Numpy array
# we want :
# * line plot
# * scatter plot
# * bar chart
# * hist
# * subplot

# %%
import numpy as np

# %%
# Create numpy data for plotting
x = np.linspace(0,10,100)
x[:20]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091,
#        1.01010101, 1.11111111, 1.21212121, 1.31313131, 1.41414141,
#        1.51515152, 1.61616162, 1.71717172, 1.81818182, 1.91919192])

# %%
# Plot the  data
fig, ax = plt.subplots()
ax.plot(x,x**2)

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
#another scatter plot

fig , ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
# make a plot of dict
name_dict = {"gagan":27, "rav":27, "sandeep":29,"nav":28}


fig, ax = plt.subplots()
ax.bar(name_dict.keys(), name_dict.values())
ax.set(title = "Name and age", xlabel = "name", ylabel = "age");

# %%
# horizonal bar chart 
name_dict = {"gagan":27, "rav":27, "sandeep":29,"nav":28}


fig, ax = plt.subplots()
ax.barh(list(name_dict.keys()), list(name_dict.values()))
ax.set(title = "Name and age", xlabel = "name", ylabel = "age");

# %%
#histogram 
data =  np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(data, bins = 50 );

# %% [markdown]
# ### Two options for subplot

# %%
#Subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows = 2 , ncols = 2, figsize =  (10,8))

# %%
# plot to each different axis
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows = 2 , ncols = 2, figsize =  (10,8))
ax1.plot(x,x/2)
ax2.hist(data)
ax3.scatter(np.random.random(100),np.random.random(100))
ax4.bar(name_dict.keys(), name_dict.values());

# %%
# Subplot option 2
fig, ax = plt.subplots(nrows = 2 , ncols = 2, figsize =  (10,8))
# plot to each different index
ax[0,0].plot(x,x/2)
ax[0,1].hist(data)
ax[1,0].scatter(np.random.random(100),np.random.random(100))
ax[1,1].bar(name_dict.keys(), name_dict.values());

# %% [markdown]
# ## Plotting from Pandas's DataFrame

# %%
import pandas as pd

# %%
# Make a dataframe 
car_sales = pd.read_csv("carsales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range("06-01-2020",periods = 1000))
tsc = ts.cumsum()
tsc.plot();

# %%
#lets plot car sales over time
#using Regular exp for manupulating Price column

car_sales["Price"] =  car_sales["Price"].str.replace('[\$\,\.]','')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales['Price'][0])
# Out:
# str

# %%
car_sales['Price']= car_sales['Price'].str[:-2] #remove last two digits of the string
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Date of Sales"] = pd.date_range("06-01-2020",periods = 10)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Date of Sales
# 0  Toyota  White         150043      4   4000    2020-06-01
# 1   Honda    Red          87899      4   5000    2020-06-02
# 2  Toyota   Blue          32549      3   7000    2020-06-03
# 3     BMW  Black          11179      5  22000    2020-06-04
# 4  Nissan  White         213095      4   3500    2020-06-05
# 5  Toyota  Green          99213      4   4500    2020-06-06
# 6   Honda   Blue          45698      4   7500    2020-06-07
# 7   Honda   Blue          54738      4   7000    2020-06-08
# 8  Toyota  White          60000      4   6250    2020-06-09
# 9  Nissan  White          31600      4   9700    2020-06-10

# %%
car_sales['total sales'] = car_sales['Price'].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Date of Sales  \
# 0  Toyota  White         150043      4   4000    2020-06-01
# 1   Honda    Red          87899      4   5000    2020-06-02
# 2  Toyota   Blue          32549      3   7000    2020-06-03
# 3     BMW  Black          11179      5  22000    2020-06-04
# 4  Nissan  White         213095      4   3500    2020-06-05
# 5  Toyota  Green          99213      4   4500    2020-06-06
# 6   Honda   Blue          45698      4   7500    2020-06-07
# 7   Honda   Blue          54738      4   7000    2020-06-08
# 8  Toyota  White          60000      4   6250    2020-06-09
# 9  Nissan  White          31600      4   9700    2020-06-10
#
#                                  total sales
# 0                                       4000
# 1                                   40005000
# 2                               400050007000
# 3                          40005000700022000
# 4                      400050007000220003500
# ...

# %%
#oh no this is not what I expected. We have to convert price columns data tpye from string to numeric

# %%
car_sales['total sales'] = car_sales['Price'].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Date of Sales  total sales
# 0  Toyota  White         150043      4   4000    2020-06-01         4000
# 1   Honda    Red          87899      4   5000    2020-06-02         9000
# 2  Toyota   Blue          32549      3   7000    2020-06-03        16000
# 3     BMW  Black          11179      5  22000    2020-06-04        38000
# 4  Nissan  White         213095      4   3500    2020-06-05        41500
# 5  Toyota  Green          99213      4   4500    2020-06-06        46000
# 6   Honda   Blue          45698      4   7500    2020-06-07        53500
# 7   Honda   Blue          54738      4   7000    2020-06-08        60500
# 8  Toyota  White          60000      4   6250    2020-06-09        66750
# 9  Nissan  White          31600      4   9700    2020-06-10        76450

# %%
car_sales.plot(x="Date of Sales",y="total sales")

# %%
car_sales['Price'] = car_sales['Price'].astype(int) #Price column was still a string
car_sales.plot(x="Odometer (KM)", y='Price',kind='scatter');

# %%
#Bar grpah 
x = np.random.rand(10,4)
x
# Out:
# array([[5.39648861e-01, 6.83663979e-01, 8.37038352e-01, 3.44537962e-01],
#        [6.17173551e-01, 2.53230298e-01, 2.63538482e-01, 9.79216219e-01],
#        [6.81373970e-02, 1.58317375e-01, 7.84618345e-01, 9.07611346e-01],
#        [1.38809582e-01, 1.54292638e-01, 8.65383800e-04, 9.89501781e-01],
#        [7.99502990e-01, 2.30993279e-01, 2.39395926e-01, 4.39826251e-02],
#        [7.67232416e-01, 8.28840070e-01, 9.18132538e-01, 3.81031245e-02],
#        [8.91019269e-01, 8.03223565e-01, 8.69530682e-01, 1.19912768e-01],
#        [3.14427237e-01, 7.96127823e-01, 8.97694132e-01, 8.94041748e-01],
#        [6.88684540e-01, 7.76917235e-01, 2.54091377e-02, 2.24102333e-02],
#        [5.79182920e-02, 3.31011377e-01, 4.36591662e-01, 7.60489818e-01]])

# %%
#Turn above data into dataFrame
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.539649  0.683664  0.837038  0.344538
# 1  0.617174  0.253230  0.263538  0.979216
# 2  0.068137  0.158317  0.784618  0.907611
# 3  0.138810  0.154293  0.000865  0.989502
# 4  0.799503  0.230993  0.239396  0.043983
# 5  0.767232  0.828840  0.918133  0.038103
# 6  0.891019  0.803224  0.869531  0.119913
# 7  0.314427  0.796128  0.897694  0.894042
# 8  0.688685  0.776917  0.025409  0.022410
# 9  0.057918  0.331011  0.436592  0.760490

# %%
df.plot.bar();

# %%
df.plot(kind='bar');

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Date of Sales  total sales
# 0  Toyota  White         150043      4   4000    2020-06-01         4000
# 1   Honda    Red          87899      4   5000    2020-06-02         9000
# 2  Toyota   Blue          32549      3   7000    2020-06-03        16000
# 3     BMW  Black          11179      5  22000    2020-06-04        38000
# 4  Nissan  White         213095      4   3500    2020-06-05        41500
# 5  Toyota  Green          99213      4   4500    2020-06-06        46000
# 6   Honda   Blue          45698      4   7500    2020-06-07        53500
# 7   Honda   Blue          54738      4   7000    2020-06-08        60500
# 8  Toyota  White          60000      4   6250    2020-06-09        66750
# 9  Nissan  White          31600      4   9700    2020-06-10        76450

# %%
car_sales.plot(x='Make',y='Odometer (KM)',kind='bar')

# %%
car_sales['Odometer (KM)'].plot(kind='hist')

# %%
car_sales['Odometer (KM)'].plot.hist(bins=20)

# %%
#Lets try another dataset- Heart disease 
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#lets check age columns distribution 
heart_disease["age"].plot.hist(bins = 40)

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize = (15,15),subplots = True);

# %% [markdown]
# ### pyplot vs matplotlib vs OO method

# %% [markdown]
# * When plotting somthing quickly, it is ok to use pyplot method
# * When plotting somthing advance, use OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method aka directly from pandas dataframe
over_50.plot(kind='scatter',x='age',y='chol',c='target');

# %%
# oo method mixed with pyplot method

fig, ax = plt.subplots(figsize = (10,6)) #ax object
over_50.plot(kind='scatter',x='age',y='chol',c='target',ax = ax);

#ax argument in plot( ) make sure that this data get plotted on ax objected that we have created 
# ax.set_xlim ([45,100])

# %%
# OO method from scratch 
fig, ax = plt.subplots(figsize = (10, 6))
#plot the data 
scatter = ax.scatter(x= over_50['age'], y= over_50['chol'], c= over_50['target']);

#customzie the plot
ax.set(title= "Heart disease vs Cholesterol Level",xlabel="age",ylabel= 'Cholesterol');

#add a legend 
ax.legend(*scatter.legend_elements(),title="Target" );
#add horizonal line of plot 
ax.axhline(over_50['chol'].mean(),linestyle ='--');
